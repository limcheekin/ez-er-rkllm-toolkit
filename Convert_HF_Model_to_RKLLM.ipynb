# %% [markdown]
# # Convert HF/GGUF models to RKLLM
# > 🗣️ The notebook is created specifically to run on Google Colab. For smaller model you can use "CPU" runtime, otherwise use "v2-8 TPU".
#
# <a href="https://colab.research.google.com/github/limcheekin/ez-er-rkllm-toolkit/blob/main/Convert_HF_Model_to_RKLLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# ❤️ Created by [@limcheekin](https://github.com/limcheekin).

# %%
# @title Change runtime to Python 3.10 (Ctrl + R to reload after executed the cell)
# %%capture
# !wget https://github.com/korakot/kora/releases/download/v0.10/py310.sh
# !bash ./py310.sh -b -f -p /usr/local
# !python -m ipykernel install --name "py310" --user

# %%
import sys
print("version:", sys.version)
# Out:
# version: 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:35:26) [GCC 10.4.0]

# %%
# Model to be converted such as "Qwen/Qwen2.5-0.5B-Instruct"
MODEL_NAME = "user/model" 

import os
os.environ["HF_TOKEN"] = "your-huggingface-token"
os.environ["HF_USERNAME"] = "your-huggingface-username"

# %%
# @title Clone the ez-er-rkllm-toolkit repository
# !git clone https://github.com/limcheekin/ez-er-rkllm-toolkit.git
# !ls -la ez-er-rkllm-toolkit
# Out:
# Cloning into 'ez-er-rkllm-toolkit'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 177 (delta 66), reused 76 (delta 49), pack-reused 80 (from 1)
# Receiving objects: 100% (177/177), 28.76 MiB | 38.25 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# total 36
# drwxr-xr-x 6 root root 4096 Mar 18 08:11 .
# drwxr-xr-x 1 root root 4096 Mar 18 08:11 ..
# drwxr-xr-x 2 root root 4096 Mar 18 08:11 docker-interactive
# drwxr-xr-x 2 root root 4096 Mar 18 08:11 docker-noninteractive
# drwxr-xr-x 8 root root 4096 Mar 18 08:11 .git
# drwxr-xr-x 3 root root 4096 Mar 18 08:11 .github
# -rw-r--r-- 1 root root 3138 Mar 18 08:11 .gitignore
# -rw-r--r-- 1 root root 6107 Mar 18 08:11 README.md

# %%
# @title Install dependencies
# %%capture
# !python3 -m pip install --upgrade pip
# !python3 -m pip install inquirer ez-er-rkllm-toolkit/docker-noninteractive/rkllm_toolkit-1.1.4-cp310-cp310-linux_x86_64.whl xformers

# %%
# @title Convert the model to RKLLM
# !python ez-er-rkllm-toolkit/docker-noninteractive/noninteractive_pipeline.py $MODEL_NAME
# Out:
# Streaming output truncated to the last 5000 lines.
# Qwen2.5-0.5B-Instruct loaded successfully!
# Building Qwen2.5-0.5B-Instruct with w8a8 quantization and optmization level 0
# Building model: 100% 343/343 [00:04<00:00, 78.47it/s]
# Qwen2.5-0.5B-Instruct built successfully!
# INFO: The token_id of eos is set to 151645
# INFO: The token_id of pad is set to 151643
# INFO: The token_id of bos is set to 151643
# Converting model: 100% 291/291 [00:00<00:00, 1449575.37it/s]
# INFO: Exporting the model, please wait ....
# [=================================================>] 513/513 (100%)
# INFO: Model has been saved to ./models/Qwen2.5-0.5B-Instruct-rk3588/Qwen2.5-0.5B-Instruct-rk3588-w8a8-opt-0-hybrid-ratio-1.0.rkllm!
# Qwen2.5-0.5B-Instruct exported successfully to ./models/Qwen2.5-0.5B-Instruct-rk3588/!
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ...

# %%
# @title Terminate Colab session programmatically (Doesn't work in this notebook)
#from google.colab import runtime
#runtime.unassign()
